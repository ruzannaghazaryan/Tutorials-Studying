# %% [markdown]
# __code blocks__

# %% [markdown]
# Whenever a line ends with a colon, Python will expect a new code block to follow it.
# <br>
# That means that the next line must be indented.
# <br>
# When you've finished all the code for a block, you remove the indentation for the next line.

# %%
for i in range(1, 3):
    print("No. {} squared is {} and cubed is {}.".format(i, i**2, i**3))
# Out:
# No. 1 squared is 1 and cubed is 1.
# No. 2 squared is 4 and cubed is 8.

# %%
for i in range(1, 3):
    print(f"No. {i} squared is {i**2} and cubed is {i**3}.")
    print()
    print()
# Out:
# No. 1 squared is 1 and cubed is 1.
#
#
# No. 2 squared is 4 and cubed is 8.

# %% [markdown]
# ___

# %% [markdown]
# !!! select lines of code and use ___shift tab___ to __remove a level of indentation.__

# %% [markdown]
# ___

# %%
for i in range(1, 3):
    print("No. {:2} squared is {:3} and cubed is {:4}.".format(i, i**2, i**3))

print('*' * 80)
# Out:
# No.  1 squared is   1 and cubed is    1.
# No.  2 squared is   4 and cubed is    8.
# ********************************************************************************

# %% [markdown]
# ____

# %%
name = input("Please enter your name: ")
# Out:
# Please enter your name: Zuzi

# %%
age = input("How old are you, {0}: ".format(name))
# Out:
# How old are you, Zuzi: 25

# %%
age, type(age)
# Out:
# ('25', str)

# %%
age = int(input("How old are you, {}: ".format(name)))
# Out:
# How old are you, Zuzi: 25

# %%
age, type(age)
# Out:
# (25, int)

# %%
if age >= 18:
    print('You\'re old enough to vote.')
else:
    print("Please come back in {0} years.".format(18-age))
# Out:
# You're old enough to vote.

# %%
if age < 18:
    print("Please come back in {0} years.".format(18-age))
elif age == 900: 
    print("Sorry, there is a mistake.")
else:
    print('You\'re old enough to vote.')
    print('Put an X in the box.')
# Out:
# You're old enough to vote.
# Put an X in the box.

# %% [markdown]
# ___

# %% [markdown]
# __Python won't test the code in an _elif_ or an _else_ when the _if_ condition is _true_.__

# %% [markdown]
# __else blocks will be executed if nothing else evaluated to true.__

# %% [markdown]
# So an if-statement begins with the keyword if, followed by condition.
# The if condition will always be evaluated.
#
# Next, you can have one or more elif blocks.
#
# And finally, you may have an else block. You don't have to use else, but if you do,
# it must come after the if, and it must also come after any elifs, if there are any.

# %% [markdown]
# An __if statement__ can include __many elif__ parts, but there can only be __one else__.

# %% [markdown]
# ___

# %%
answer = 5

print('Please guess number between 1 and 10: ')
guess = int(input())

if guess < answer:
    print('Please guess higher.')
    guess = int(input())
    if guess == answer:
        print('Well done, you guessed it.')
    else:
        print('Incorrect guess again.')
elif guess > answer:
    print('Please guess lower.')
    guess = int(input())
    if guess == answer:
        print('Well done, you guessed it.')
    else:
        print('Incorrect guess again.')
else:
    print('You got it immediately.')
# Out:
# Please guess number between 1 and 10:
# 7
# Please guess lower.
# 6
# Incorrect guess again.

# %% [markdown]
# We've duplicated exactly the same code in the if and elif blocks.
#
# Whenever you see duplication like this happening, that's a good indication that it can be done better.
#
# Duplicating code is generally a bad idea. There's almost always a better way.

# %%
answer = 5

print('Please guess number between 1 and 10: ')
guess = int(input())

if guess != answer:
    if guess < answer:
        print('Please guess higher.')
    else:
        print('Please guess lower.')
    guess = int(input())
    if guess == answer:
        print('Well done, you guessed it.')
    else:
        print("Sorry, you've not guessed correctly.")
else:
    print('You got it immediately.')
# Out:
# Please guess number between 1 and 10:
# 3
# Please guess higher.
# 8
# Sorry, you've not guessed correctly.

# %% [markdown]
# ___

# %% [markdown]
# __Comparison operators__
# <br> >
# <br> >=
# <br> <
# <br> <=
# <br> ==
# <br> !=

# %% [markdown]
# ___

# %% [markdown]
# Using __and, or, in__ Conditions

# %%
age = int(input('How old are you? '))
# Out:
# How old are you? 25

# %%
if age >= 16 and age < 63:
    print('Have a good day at work.')
# Out:
# Have a good day at work.

# %% [markdown]
# Let's look at simplifying chained comparisons. <br> When dealing with numerical values in a condition, you can often replace and with a simpler comparison.

# %%
age = int(input('How old are you? '))

if 16 <= age < 63:
    print('Have a good day at work.')
else:
    print("Enjoy your free time.")

print('-' * 80)

if age < 16 or age >= 63:
    print("Enjoy your free time.")
else:
    print("Have a good day at work.")
# Out:
# How old are you? 25
# Have a good day at work.
# --------------------------------------------------------------------------------
# Have a good day at work.

# %% [markdown]
# ___

# %% [markdown]
# A __boolean value__ is a value that can either be __True__ or __False__.
#
# __Not__ is used to reverse the value.

# %%
# age greater than equal to 16 is a boolean expression
# name == Tim, so that's a boolean expression that will evaluate to True if the value of name equals the string Tim.

# %%
day = "Monday"
temperature = 30
raining = True

if day == 'Saturday' and temperature > 27 and not raining:
    print('Go swimming')
else:
    print('Learn Python')
# Out:
# Learn Python

# %%
day = "Saturday"
temperature = 30
raining = True

if day == 'Saturday' and temperature > 27 and not raining:
    print('Go swimming')
else:
    print('Learn Python')
    

# All three parts of the condition must evaluate to True in order for the entire condition to be true. 
# The last part of the condition is: and not raining.
# So raining is true, as we can see on line 3. That means that not raining is false.
# Out:
# Learn Python

# %%
# change and -> or (True or False => True)

day = "Saturday"
temperature = 30
raining = True

if day == 'Saturday' and temperature > 27 or not raining:
    print('Go swimming')
else:
    print('Learn Python')
# Out:
# Go swimming

# %% [markdown]
# https://docs.python.org/3/reference/expressions.html#operator-precedence

# %%
# the above code doesn't really give you any indication of what I intended.
# we should use parentheses to make it clear.

# %%
day = "Friday"
temperature = 30
raining = False

if day == 'Saturday' and temperature > 27 or not raining:
    print('Go swimming')
else:
    print('Learn Python')
    
# False and True or True
# and has a higher precedence than or
# False or True => True
# Out:
# Go swimming

# %% [markdown]
# ### `and` has a higher precedence than `or`

# %%
# to make the code much easier to read.

day = "Friday"
temperature = 30
raining = False

if (day == 'Saturday' and temperature > 27) or not raining:
    print('Go swimming')
else:
    print('Learn Python')
# Out:
# Go swimming

# %% [markdown]
# ___

# %% [markdown]
# https://docs.python.org/3/library/stdtypes.html

# %% [markdown]
# By default, an object is considered true unless its class defines either a __bool__() method that returns False or a __len__() method that returns zero, when called with the object. Here are most of the built-in objects considered false:
#
# * constants defined to be false: None and False.
#
# * zero of any numeric type: 0, 0.0, 0j, Decimal(0), Fraction(0, 1)
#
# * empty sequences and collections: '', (), [], {}, set(), range(0)

# %%
# Python expects a boolean expression after if, which is why it tries to evaluate 0 and name as boolean values. 
# We've already seen that 0 evaluates to False.

if 0:
    print('True')
else:
    print('False')
# Out:
# False

# %%
name = input('Please enter your name: ')

if name:
    print('Hello, {}'.format(name))
else:
    print('Are you the man with no name')
    
# Because Zazu isn't an empty string, it evaluates as True.
# Out:
# Please enter your name: Zazu
# Hello, Zazu

# %%
# It's more obvious what we're doing there and that's the way I suggest you write your conditions to begin with.

if name != '':
    print('Hello, {}'.format(name))
else:
    print('Are you the man with no name')
# Out:
# Hello, Zazu

# %% [markdown]
# __in__ and __not in__

# %%
parrot = 'Norwegian Blue'

letter = input('Please enter a character: ')

if letter in parrot:
    print("{} is in {}".format(letter, parrot))
else:
    print("I don't need that letter")
# Out:
# Please enter a character: i
# i is in Norwegian Blue

# %%
# Remember that string comparisons are case-sensitive.
# If you enter a capital A it won't be found in the string.

parrot = 'Norwegian Blue'

letter = input('Please enter a character: ')

if letter in parrot:
    print("{} is in {}".format(letter, parrot))
else:
    print("I don't need that letter")
# Out:
# Please enter a character: A
# I don't need that letter

# %%
parrot = 'Norwegian Blue'

letter = input('Please enter a character: ')

if letter in parrot:
    print("{} is in {}".format(letter, parrot))
else:
    print("I don't need that letter")
# Out:
# Please enter a character: Blue
# Blue is in Norwegian Blue

# %%
parrot = 'Norwegian Blue'

letter = input('Please enter a character: ')

if letter in parrot:
    print("{} is in {}".format(letter, parrot))
else:
    print("I don't need that letter")
# Out:
# Please enter a character: blue
# I don't need that letter

# %% [markdown]
# ___

# %%
# not in

activity = input("What would you like to learn today? ")

if 'cinema' not in activity:
    print('But I want to go to the cinema.')
# Out:
# What would you like to learn today? I want to learn Python
# But I want to go to the cinema.

# %%
activity = input("What would you like to learn today? ")

if 'cinema' not in activity:
    print('But I want to go to the cinema.')
    
# case-sensitive (capital letter)
# Out:
# What would you like to learn today? I'm going to the Cinema
# But I want to go to the cinema.

# %% [markdown]
# #### `.casefold()` method

# %% [markdown]
# __casefold() function converts a string to lowercase__

# %%
activity.casefold()
# Out:
# "i'm going to the cinema"

# %%
activity = input("What would you like to learn today? ")

if 'cinema' not in activity.casefold():
    print('But I want to go to the cinema.')
# Out:
# What would you like to learn today? I want to go to the Cinema

# %% [markdown]
# ___

# %% [markdown]
# Look through, please
#
# https://docs.python.org/3/library/stdtypes.html#string-methods

# %% [markdown]
# ___

# %%
name = input('Please enter your name: ')
age = int(input("How old are you? "))

if 18 <= age < 31:
    print('Welcome club 18-30 holidays, {}.'.format(name))
else:
    print('Sorry, our holidays are only for cool people.')
# Out:
# Please enter your name: Zazu
# How old are you? 25
# Welcome club 18-30 holidays, Zazu.

# %% [markdown]
# ___

# %% [markdown]
# **for loops**

# %%
parrot = 'Norwegian Blue'

for character in parrot:
    print(character)
# Out:
# N
# o
# r
# w
# e
# g
# i
# a
# n
#
# B
# l
# u
# e

# %% [markdown]
# #### `.isnumeric()` method

# %%
number = '9,223;372:036 854,775;807'
separators = ''

for char in number:
    if not char.isnumeric():
        separators = separators + char

print(separators)
# Out:
# ,;: ,;

# %%
values = ''.join(char if char not in separators else ' ' for char in number).split(' ')
print(values)
print([int(char) for char in values])
print(sum([int(char) for char in values]))
# Out:
# ['9', '223', '372', '036', '854', '775', '807']
# [9, 223, 372, 36, 854, 775, 807]
# 3076

# %% [markdown]
# ___

# %% [markdown]
# https://docs.python.org/3/library/functions.html

# %% [markdown]
# ___

# %% [markdown]
# #### `.isupper()` method

# %%
quote = """
            Alright, but apart from the Sanitation, the Medicine, Education, Wine,
            Public Order, Irrigation, Roads, the Fresh-Water System,
            and Public Health, what have the Romans ever done for us?
        """
 
# Use a for loop and an if statement to print just the capitals in the quote above.
for i in quote:
    if i.isupper():
        print(i)
# Out:
# A
# S
# M
# E
# W
# P
# O
# I
# R
# F
# W
# S
# P
# H
# R

# %% [markdown]
# #### `.islower()` method

# %%
test = '    nk?LiKiu.jk;'
for i in test:
    if not i.islower():
        print(i)
# Out:
#
#
#
#
# ?
# L
# K
# .
# ;

# %% [markdown]
# ___

# %% [markdown]
# ### range

# %%
for i in range(10):
    print("i now is {}".format(i))
# Out:
# i now is 0
# i now is 1
# i now is 2
# i now is 3
# i now is 4
# i now is 5
# i now is 6
# i now is 7
# i now is 8
# i now is 9

# %%
# specifying a step
for i in range(0, 10, 2):
    print("i now is {}".format(i))
# Out:
# i now is 0
# i now is 2
# i now is 4
# i now is 6
# i now is 8

# %%
# backwards
for i in range(10, 0, -2):
    print("i now is {}".format(i))
# Out:
# i now is 10
# i now is 8
# i now is 6
# i now is 4
# i now is 2

# %%
age = int(input())
if age in range(16, 63):
    print('Have a good day at work.')
# Out:
# 25
# Have a good day at work.

# %% [markdown]
# Write a program to print out all the numbers from 0 to 100 that are divisible by 7.

# %%
for i in range(101):
    if i % 7 == 0:
        print(i)
# Out:
# 0
# 7
# 14
# 21
# 28
# 35
# 42
# 49
# 56
# 63
# 70
# 77
# 84
# 91
# 98

# %%
for i in range(0, 101, 7):
    print(i)
# Out:
# 0
# 7
# 14
# 21
# 28
# 35
# 42
# 49
# 56
# 63
# 70
# 77
# 84
# 91
# 98

# %% [markdown]
# ___

# %% [markdown]
# ### Nested for loops

# %%
# Multiplication table
for i in range(1, 5):
    for j in range(1, 5):
        print('{0} times {1} is {2}'.format(i, j, i*j))
    print('----------------------------------------------')
# Out:
# 1 times 1 is 1
# 1 times 2 is 2
# 1 times 3 is 3
# 1 times 4 is 4
# ----------------------------------------------
# 2 times 1 is 2
# 2 times 2 is 4
# 2 times 3 is 6
# 2 times 4 is 8
# ----------------------------------------------
# 3 times 1 is 3
# 3 times 2 is 6
# 3 times 3 is 9
# 3 times 4 is 12
# ----------------------------------------------
# 4 times 1 is 4
# 4 times 2 is 8
# 4 times 3 is 12
# 4 times 4 is 16
# ----------------------------------------------

# %% [markdown]
# ### continue

# %%
shopping_list = ['milk', 'pasta', 'eggs', 'spam', 'bread', 'rice']

# %%
for item in shopping_list:
    print('Buy ' + item)
# Out:
# Buy milk
# Buy pasta
# Buy eggs
# Buy spam
# Buy bread
# Buy rice

# %% [markdown]
# But what if we don't like spam?
# <br> Well we've seen one way to deal with that. <br> We could check for the current item
# not being spam before printing the reminder.

# %%
for item in shopping_list:
    if item != 'spam':
        print('Buy ' + item)
# Out:
# Buy milk
# Buy pasta
# Buy eggs
# Buy bread
# Buy rice

# %% [markdown]
# but there's another way in loops and that's to use __continue__
#
# __continue causes all the remaining code in the block to be skipped, so execution will jump straight back to the for statement.__

# %%
for item in shopping_list:
    if item == 'spam':
        continue
    print('Buy ' + item)
# Out:
# Buy milk
# Buy pasta
# Buy eggs
# Buy bread
# Buy rice

# %% [markdown]
# https://stackoverflow.com/questions/8420705/example-use-of-continue-statement-in-python

# %%
def filter_out_colors(elements):
    colors = ['red', 'green']
    result = []
    for element in elements:
        if element in colors:
            continue # skip the element
        result.append(element)
    return result

filter_out_colors(['lemon', 'orange', 'red', 'pear'])
# Out:
# ['lemon', 'orange', 'pear']

# %%
commit_times = [(8,20), (9,30), (11, 45), (15, 50), (17, 45), (27, 132)]

for time in commit_times:
    hour = time[0]
    minutes = time[1]

    if not (0 <= hour <= 24 and 0 <= minutes <= 59):
        continue

    print("Someone commited at {h}:{m}".format(h=hour, m=minutes))
# Out:
# Someone commited at 8:20
# Someone commited at 9:30
# Someone commited at 11:45
# Someone commited at 15:50
# Someone commited at 17:45

# %% [markdown]
# ### break
# __break causes Python to jump out of the loop__

# %% [markdown]
# It's also possible to break out of a for loop completely, using the break statement.

# %% [markdown]
# The break terminates the loop, and also prevents the else block from executing.

# %%
shopping_list
# Out:
# ['milk', 'pasta', 'eggs', 'spam', 'bread', 'rice']

# %%
# the loop will terminate when it gets to spam

for item in shopping_list:
    if item == 'spam':
        break
    print(f'Buy {item}')
# Out:
# Buy milk
# Buy pasta
# Buy eggs

# %%
for item in shopping_list:
    print(f'Buy {item}')
    if item == 'spam':
        break
# Out:
# Buy milk
# Buy pasta
# Buy eggs
# Buy spam

# %% [markdown]
# ___

# %% [markdown]
# __None__ is a constant that's used to show that something doesn't have a value, so it's roughly equivalent to null in C or Java.

# %%
shopping_list = ['milk', 'pasta', 'eggs', 'spam', 'bread', 'rice']

item_to_find = 'spam'
found_at = None

# So we're gonna search for 'spam'. If we find it, we want to know its position in the list.
for index in range(len(shopping_list)):
    if shopping_list[index] == item_to_find:
        found_at = index

print(found_at)
# We found what we're looking for and there's no point continuing to search, but the code's still searching.
# Out:
# 3

# %%
# So this is where break can be useful.

for index in range(len(shopping_list)):
    if shopping_list[index] == item_to_find:
        found_at = index
        break
        
print(found_at)
# Out:
# 3

# %% [markdown]
# ___

# %%
# item which is not in the list

shopping_list = ['milk', 'pasta', 'eggs', 'spam', 'bread', 'rice']

item_to_find = 'albatross'
found_at = None

for index in range(len(shopping_list)):
    if shopping_list[index] == item_to_find:
        found_at = index
        break

print(found_at)
# Out:
# None

# %%
# restart kernel, then run the below code
# let's see what would have happened if we hadn't have defined 'found_at' variable.

shopping_list = ['milk', 'pasta', 'eggs', 'spam', 'bread', 'rice']

item_to_find = 'albatross'
# found_at = None

for index in range(len(shopping_list)):
    if shopping_list[index] == item_to_find:
        found_at = index
        break

print(found_at)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-feb47d0f4cc6> in <module>
#      12         break
#      13
# ---> 14 print(found_at)
#
# NameError: name 'found_at' is not defined

# %%
shopping_list = ['milk', 'pasta', 'eggs', 'spam', 'bread', 'rice']

item_to_find = 'albatross'
found_at = None

for index in range(len(shopping_list)):
    if shopping_list[index] == item_to_find:
        found_at = index
        break

if found_at is not None:
    print("Item found at position {}".format(found_at))
else:
    print('{} item not found'.format(item_to_find))
# Out:
# albatross item not found

# %%
if item_to_find in shopping_list:
    found_at = shopping_list.index(item_to_find)

if found_at is not None:
    print("Item found at position {}".format(found_at))
else:
    print('{} item not found'.format(item_to_find))
# Out:
# albatross item not found

# %% [markdown]
# ___

# %% [markdown]
# ### while loop

# %% [markdown]
# Sometimes we need to keep looping as long as some condition is true and stop when it becomes False.
# We do this using a while loop.

# %%
i = 0
while i < 10:
    print('i is now {}'.format(i))
    i += 1
print('end')
# Out:
# i is now 0
# i is now 1
# i is now 2
# i is now 3
# i is now 4
# i is now 5
# i is now 6
# i is now 7
# i is now 8
# i is now 9
# end

# %% [markdown]
# __So that leads to two other important things to consider.__
# <br>* First, the condition must be initialized before the while loop starts.
# With the for loop, we just used i without setting a value first.
# With the while loop though, we have to give i a value first. If we hadn't, we'd get an error that i is not defined.
# <br>* The second thing is that we need some way within the loop, for the condition to become False. Otherwise, the condition never becomes False and the loop will keep running forever.

# %%
available_exits = ['north', 'south', 'east', 'west']

chosen_exit = ''
while chosen_exit not in available_exits:
    chosen_exit = input('Please choose a direction: ')
# Out:
# Please choose a direction: north_east
# Please choose a direction: west

# %% [markdown]
# One of the important features of while loops is that they can be used when you can't determine, in advance, how many times you will need to loop. <br>A for loop will repeat for each item in a predetermined sequence, whereas with a while loop you don't need to know how many times the loop will execute.

# %% [markdown]
# ### break in a while loop

# %%
available_exits = ['north', 'south', 'east', 'west']

chosen_exit = ''
while chosen_exit not in available_exits:
    chosen_exit = input('Please choose a direction: ')
    if chosen_exit == 'quit':
        print('Game Over')
        break
# Out:
# Please choose a direction: up
# Please choose a direction: quit
# Game Over

# %%
# Because string comparisons are case sensitive, quit with a capital Q doesn't match the string we're checking for, so

available_exits = ['north', 'south', 'east', 'west']

chosen_exit = ''
while chosen_exit not in available_exits:
    chosen_exit = input('Please choose a direction: ')
    if chosen_exit.casefold() == 'quit':
        print('Game Over')
        break
# Out:
# Please choose a direction: down
# Please choose a direction: up
# Please choose a direction: Quit
# Game Over

# %%
# Modify the code so that it stops printing when it reaches a number greater than zero that's exactly divisible by 11

# for i in range(0, 100, 7):
    # print(i)
    
for i in range(0, 100, 7):
    print(i)
    if i > 0 and i % 11 == 0:
        break
# Out:
# 0
# 7
# 14
# 21
# 28
# 35
# 42
# 49
# 56
# 63
# 70
# 77

# %%
# Write a program to print out all the numbers from 0 to 20 that aren't divisible by either 3 or 5.
# (Zero is considered divisible by everything (zero should not appear in the output))

for i in range(21):
    if i >= 0 and (i % 3 == 0 or i % 5 == 0):
        continue
    print(i)
    
# this is a solution with continue statement
# Out:
# 1
# 2
# 4
# 7
# 8
# 11
# 13
# 14
# 16
# 17
# 19

# %%
# this is a solution without continue statement

for x in range(21):
    if x % 3 != 0 and x % 5 != 0:
        print(x)
# Out:
# 1
# 2
# 4
# 7
# 8
# 11
# 13
# 14
# 16
# 17
# 19

# %% [markdown]
# ___

# %% [markdown]
# ### The random module and import

# %%
# There's a number of problems with this game. One problem is that it only allows two guesses.

answer = 5

print('Please guess number between 1 and 10: ')
guess = int(input())

if guess != answer:
    if guess < answer:
        print('Please guess higher.')
    else:
        print('Please guess lower.')
    guess = int(input())
    if guess == answer:
        print('Well done, you guessed it.')
    else:
        print("Sorry, you've not guessed correctly.")
else:
    print('You got it immediately.')
# Out:
# Please guess number between 1 and 10:
# 6
# Please guess lower.
# 2
# Sorry, you've not guessed correctly.

# %%
import random

highest = 10
# randomly generate a number
answer = random.randint(1, highest) # the randint function is in the random module.

print('Please guess number between 1 and {}: '.format(highest))
guess = int(input())

if guess != answer:
    if guess < answer:
        print('Please guess higher.')
    else:
        print('Please guess lower.')
    guess = int(input())
    if guess == answer:
        print('Well done, you guessed it.')
    else:
        print("Sorry, you've not guessed correctly.")
else:
    print('You got it immediately.')
# Out:
# Please guess number between 1 and 10:
# 5
# Please guess lower.
# 3
# Sorry, you've not guessed correctly.

# %%
# to check for zero and break out of the loop if zero was typed

import random

highest = 10
answer = random.randint(1, highest)

guess = 0

while guess != answer:
    guess = int(input())
    if guess == 0:
        break
    
    if guess == answer:
        print('Well done, you guessed it.')
        break
    else:
        if guess < answer:
            print('Please guess higher')
        else:
            print('Please guess lower')
# Out:
# 2
# Please guess higher
# 6
# Please guess higher
# 0

# %% [markdown]
# ___

# %% [markdown]
# ### Hi Lo Game
# __Guessing a number between 1 and 1000__

# %% [markdown]
# <br> The computer should be able to get the correct answer with 10 guesses, at most.
# <br> That's because we're halving the range of numbers each time, and two to the power of 10 is 1024. So that's slightly more than 1000. In fact, the computer can guess any number from 1 to 1023 within 10 guesses.

# %%
from PIL import Image

# %%
Image.open(r"C:\Users\Dell\Documents\GitHub\Tutorials-Studying\Udemy - Python Programming Masterclass\\binary_search1.jpg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1051x1280 at 0x2A79F462748>

# %%
Image.open(r"C:\Users\Dell\Documents\GitHub\Tutorials-Studying\Udemy - Python Programming Masterclass\\binary_search2.jpg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=978x1280 at 0x2A79F462E48>

# %% [markdown]
# while True:
# <br> ----------
#
# ----------------------------------------
#
# True is always true, which means this loop will go round forever.
# <br>
# Sometimes it's easier to do that then break out of the loop at some point, rather than trying to include a condition in the while loop.

# %%
low = 1 
high = 1000

print(f'Please think of a number between {low} and {high}')
input('Press ENTER to start')

guesses = 1
while True:
    guess = low + (high - low)//2 
    high_low = input(f'My guess is {guess}. Should I guess higher or lower?' 
                     'Enter h or l or c if my guess was correct.').casefold()
    
    if high_low == 'h':
        # Guess higher
    elif high_low == 'l':
        # Guess lower
    elif high_low == 'c':
        print('I got it in {} guesses'.format(guesses))
    else:
        print('Please enter h, l or c')
# Out:
#   File "<ipython-input-42-015519c2d843>", line 15
#     elif high_low == 'l':
#        ^
# IndentationError: expected an indented block

# %% [markdown]
# We've got errors because you must have valid code inside each of the code blocks. A comment doesn't count.

# %% [markdown]
# What you'll often find programmers doing, is adding a dummy bit of code inside the indented block, to clear this error.<br>
# __So there's a specific keyword in Python for that and that's called _pass___.
#
# pass doesn't do anything, but it makes the code syntactically correct. So think of it __as a placeholder for the real code that you'll add later__.

# %%
low = 1 
high = 1000

print(f'Please think of a number between {low} and {high}')
input('Press ENTER to start')

guesses = 1
while True:
    print('\tGuessing in the range of {} and {}.'.format(low, high))
    guess = low + (high - low)//2 
    high_low = input(f'My guess is {guess}. Should I guess higher or lower? ' 
                     'Enter h or l or c if my guess was correct.').casefold()
    
    if high_low == 'h': # Guess higher
        low = guess + 1
    elif high_low == 'l': # Guess lower
        high = guess - 1
    elif high_low == 'c':
        print('I got it in {} guesses'.format(guesses))
        break
    else:
        print('Please enter h, l or c')
    
    guesses += 1
# Out:
# Please think of a number between 1 and 1000
# Press ENTER to start
# 	Guessing in the range of 1 and 1000.
# My guess is 500. Should I guess higher or lower? Enter h or l or c if my guess was correct.l
# 	Guessing in the range of 1 and 499.
# My guess is 250. Should I guess higher or lower? Enter h or l or c if my guess was correct.
# Please enter h, l or c
# 	Guessing in the range of 1 and 499.
# My guess is 250. Should I guess higher or lower? Enter h or l or c if my guess was correct.h
# 	Guessing in the range of 251 and 499.
# My guess is 375. Should I guess higher or lower? Enter h or l or c if my guess was correct.l
# 	Guessing in the range of 251 and 374.
# My guess is 312. Should I guess higher or lower? Enter h or l or c if my guess was correct.h
# 	Guessing in the range of 313 and 374.
# My guess is 343. Should I guess higher or lower? Enter h or l or c if my guess was correct.l
# 	Guessing in the range of 313 and 342.
# My guess is 327. Should I guess higher or lower? Enter h or l or c if my guess was correct.l
# 	Guessing in the range of 313 and 326.
# My guess is 319. Should I guess higher or lower? Enter h or l or c if my guess was correct.h
# 	Guessing in the range of 320 and 326.
# My guess is 323. Should I guess higher or lower? Enter h or l or c if my guess was correct.h
# 	Guessing in the range of 324 and 326.
# My guess is 325. Should I guess higher or lower? Enter h or l or c if my guess was correct.h
# 	Guessing in the range of 326 and 326.
# My guess is 326. Should I guess higher or lower? Enter h or l or c if my guess was correct.c
# I got it in 11 guesses

# %% [markdown]
# So we've written the code to get the computer to guess a number we think of.

# %% [markdown]
# ___

# %% [markdown]
# ___

# %% [markdown]
# ### Augmented Assignment
# <br>It's just a shorthand way of assigning values to a variable.
# <br>The symbol for them is just the binary operator - plus minus multiplication division, followed by an equal sign.

# %%
guesses = guesses + 1
guesses += 1 # efficient code

# %% [markdown]
# Augmented assignment is more efficient in Python. With our first form Python creates a new variable. It binds that new variable to the result of performing the calculation, then destroys the original variable.<br>Using an Augmented assignment, you can perform the operation in-place where possible, modifying the original variable instead of creating a new one.

# %%
x = 23

# %%
x += 1
print(x)
# Out:
# 24

# %%
x -= 4
print(x)
# Out:
# 20

# %%
x *= 5
print(x)
# Out:
# 100

# %%
x //= 4
print(x)
# Out:
# 25

# %%
x /= 5 # conversion from int to float
print(x)
# Out:
# 5.0

# %%
x **= 2
print(x)
# Out:
# 25.0

# %%
x %= 5
print(x)
# Out:
# 0.0

# %%
# with strings

greeting = 'good'
greeting += ' morning'
print(greeting)

greeting *= 5
print(greeting)
# Out:
# good morning
# good morninggood morninggood morninggood morninggood morning

# %% [markdown]
# ___

# %% [markdown]
# ### PEP8: The Python Style Guide
# https://www.python.org/dev/peps/pep-0008/

# %% [markdown]
# ___

# %% [markdown]
# ### else in a loop

# %% [markdown]
# We've seen else when we looked at testing conditions using if, but it can also be used at the end of loops.

# %% [markdown]
# So let's assume we've noticed that lottery numbers divisible by 8 are less likely to appear.

# %% [markdown]
# The break terminates the loop, and also prevents the else block from executing.

# %%
numbers = [1, 45, 32, 12, 60]

for number in numbers:
    if number % 8 == 0:
        # reject the list
        print('numbers are unacceptable')
        break
        
# these numbers should be rejected because we've got the value 32 in the list.
# Out:
# numbers are unacceptable

# %%
# But let's see what happens with the list of numbers that aren't divisible by 8.
# So I'm going to change the 32 to a 31.

numbers = [1, 45, 31, 12, 60]

for number in numbers:
    if number % 8 == 0:
        # reject the list
        print('numbers are unacceptable')
        break

# %% [markdown]
# So the code works but it's not very friendly. It hasn't given us any output. So what would be a lot friendlier, is if we've got a message saying that these numbers were okay.

# %%
numbers = [1, 45, 31, 12, 60]

for number in numbers:
    if number % 8 == 0:
        # reject the list
        print('numbers are unacceptable')
        break
else:
    print('numbers are fine')
# Out:
# numbers are fine

# %% [markdown]
# ___

# %% [markdown]
# ### else in the Hi Lo game

# %%
low = 1 
high = 1000

print(f'Please think of a number between {low} and {high}')
input('Press ENTER to start')

guesses = 1
while True:
    print('\tGuessing in the range of {} and {}.'.format(low, high))
    guess = low + (high - low)//2 
    high_low = input(f'My guess is {guess}. Should I guess higher or lower? ' 
                     'Enter h or l or c if my guess was correct.').casefold()
    
    if high_low == 'h': # Guess higher
        low = guess + 1
    elif high_low == 'l': # Guess lower
        high = guess - 1
    elif high_low == 'c':
        print('I got it in {} guesses'.format(guesses))
        break
    else:
        print('Please enter h, l or c')
    
    guesses += 1

# %%
low = 1 
high = 1000

print(f'Please think of a number between {low} and {high}')
input('Press ENTER to start')

guesses = 1
while low != high:
    print('\tGuessing in the range of {} and {}.'.format(low, high))
    guess = low + (high - low)//2 
    high_low = input(f'My guess is {guess}. Should I guess higher or lower? ' 
                     'Enter h or l or c if my guess was correct.').casefold()
    
    if high_low == 'h': # Guess higher
        low = guess + 1
    elif high_low == 'l': # Guess lower
        high = guess - 1
    elif high_low == 'c':
        print('I got it in {} guesses'.format(guesses))
        break
    else:
        print('Please enter h, l or c')
    
    guesses += 1
else:
    print(f"You thought of the number {low}.")
    print("I got it in {} guesses".format(guesses))

# %%
if arrTime >= ata:
    eta = arrTime
    waitingTimes.append(0)
    departTimes.append(eta + timedelta(seconds = df['serviceTime'][i+1]))
else:
    arrTimeDur = (arrTime - startTime).total_seconds() - (c-1) * recharge
    ataDur = (ata - startTime).total_seconds() - (c-1) * recharge
    if arrTimeDur <= shiftInterval <= ataDur:
        remainder = ataDur - shiftInterval
        if remainder <= recharge:
            eta = startTime + timedelta(seconds = shiftInterval + c * recharge)
            shiftInterval += shift
            c += 1
        else:
            eta = startTime + timedelta(seconds = shiftInterval + c * recharge)
            shiftInterval += shift
            c += 1
            remainder = (ata - eta).total_seconds()
            while remainder >= shift:
                eta += timedelta(seconds = shift + recharge)
                shiftInterval += shift
                c += 1
                remainder = (ata - eta).total_seconds()
                if remainder < 0:
                    break
            else:
                eta = ata
    elif ataDur < shiftInterval:
        eta = ata

# %% [markdown]
# ___

# %%
available_exits = ['north', 'south', 'east', 'west']

chosen_exit = ''
while chosen_exit not in available_exits:
    chosen_exit = input('Please choose a direction: ')
    if chosen_exit.casefold() == 'quit':
        print('Game Over')
        break
# Out:
# Please choose a direction: up
# Please choose a direction: north

# %%
available_exits = ['north', 'south', 'east', 'west']

chosen_exit = ''
while chosen_exit not in available_exits:
    chosen_exit = input('Please choose a direction: ')
    if chosen_exit.casefold() == 'quit':
        print('Game Over')
        break
else:
    print('aren\'t you glad you got out of there')
# Out:
# Please choose a direction: up
# Please choose a direction: quit
# Game Over

# %%
available_exits = ['north', 'south', 'east', 'west']

chosen_exit = ''
while chosen_exit not in available_exits:
    chosen_exit = input('Please choose a direction: ')
    if chosen_exit.casefold() == 'quit':
        print('Game Over')
        break
else:
    print('aren\'t you glad you got out of there')
# Out:
# Please choose a direction: east
# aren't you glad you got out of there

# %% [markdown]
# ___

# %%
# summary challenge

print('Please choose your option from the list below: ')
print('1:\tLearn Python')
print('2:\tLearn Java')
print('3:\tGo swimming')
print('4:\tHave dinner')
print('5:\tGo to bed')
print('0:\tExit')
# Out:
# Please choose your option from the list below:
# 1:	Learn Python
# 2:	Learn Java
# 3:	Go swimming
# 4:	Have dinner
# 5:	Go to bed
# 0:	Exit

# %%
while True:
    choice = input()
    
    if choice == '0':
        break
    elif choice in '12345':
        print(f'You chose {choice}')
    else:
        print('Please choose your option from the list below: ')
        print('1:\tLearn Python')
        print('2:\tLearn Java')
        print('3:\tGo swimming')
        print('4:\tHave dinner')
        print('5:\tGo to bed')
        print('0:\tExit')
# Out:
# 1
# You chose 1
# 4
# You chose 4
# 0

# %%
while True:
    choice = input()
    
    if choice == '0':
        break
    elif choice in '12345':
        print(f'You chose {choice}')
    else:
        print('Please choose your option from the list below: ')
        print('1:\tLearn Python')
        print('2:\tLearn Java')
        print('3:\tGo swimming')
        print('4:\tHave dinner')
        print('5:\tGo to bed')
        print('0:\tExit')
# Out:
# 1
# You chose 1
# 4
# You chose 4
# 7
# Please choose your option from the list below:
# 1:	Learn Python
# 2:	Learn Java
# 3:	Go swimming
# 4:	Have dinner
# 5:	Go to bed
# 0:	Exit
# 0

# %%
choice = '-'
while True:
    if choice == '0':
        break
    elif choice in '12345':
        print(f'You chose {choice}')
    else:
        print('Please choose your option from the list below: ')
        print('1:\tLearn Python')
        print('2:\tLearn Java')
        print('3:\tGo swimming')
        print('4:\tHave dinner')
        print('5:\tGo to bed')
        print('0:\tExit')
        
    choice = input()
# Out:
# Please choose your option from the list below:
# 1:	Learn Python
# 2:	Learn Java
# 3:	Go swimming
# 4:	Have dinner
# 5:	Go to bed
# 0:	Exit
# 3
# You chose 3
# 5
# You chose 5
# 0

# %%
choice = '-'

while choice != '0':
    if choice in '12345':
        print(f'You chose {choice}')
    else:
        print('Please choose your option from the list below: ')
        print('1:\tLearn Python')
        print('2:\tLearn Java')
        print('3:\tGo swimming')
        print('4:\tHave dinner')
        print('5:\tGo to bed')
        print('0:\tExit')
        
    choice = input()
else:
    print('Exit')
# Out:
# Please choose your option from the list below:
# 1:	Learn Python
# 2:	Learn Java
# 3:	Go swimming
# 4:	Have dinner
# 5:	Go to bed
# 0:	Exit
# 1
# You chose 1
# 3
# You chose 3
# 2
# You chose 2
# 4
# You chose 4
# 5
# You chose 5
# 6
# Please choose your option from the list below:
# 1:	Learn Python
# 2:	Learn Java
# 3:	Go swimming
# 4:	Have dinner
# 5:	Go to bed
# 0:	Exit
# 0
# Exit

# %%
choice = '-'

while choice != '0':
    if choice in '12345':
        print(f'You chose {choice}')
    else:
        print('Please choose your option from the list below: ')
        print('1:\tLearn Python')
        print('2:\tLearn Java')
        print('3:\tGo swimming')
        print('4:\tHave dinner')
        print('5:\tGo to bed')
        print('0:\tExit')
        
    choice = input()
# Out:
# Please choose your option from the list below:
# 1:	Learn Python
# 2:	Learn Java
# 3:	Go swimming
# 4:	Have dinner
# 5:	Go to bed
# 0:	Exit
# 1
# You chose 1
# 2
# You chose 2
# 0

# %% [markdown]
# ___

# %% [markdown]
# __and__ has higher precedence than __or__

# %% [markdown]
# ___

# %%
choice = None
 
while choice != '0':
    choice = input("Please enter your choice.  Press enter to quit")
    if choice == '':
        break
 
    print("You have selected {}".format(choice))
else:
    print("Thank you for playing, please call back soon.")
# Out:
# Please enter your choice.  Press enter to quit0
# You have selected 0
# Thank you for playing, please call back soon.

# %% [markdown]
# ___
