# %% [markdown]
# If you are planning on going out to see a movie, how well can you trust online reviews and ratings? *Especially* if the same company showing the rating *also* makes money by selling movie tickets. Do they have a bias towards rating movies higher than they should be rated?
#
# ----
#
# __Question to answer:__
#
#   - Is there a conflict of interest for a website that both sells movie tickets and displays review ratings?
#
# ---
#
# __The article:__ [Be Suspicious Of Online Movie Ratings, Especially Fandango’s](http://fivethirtyeight.com/features/fandango-movies-ratings/)**

# %% [markdown]
# ----
# ### The Data
#
# https://github.com/fivethirtyeight/data. There are two csv files, one with Fandango Stars and Displayed Ratings, and the other with aggregate data for movie ratings from other sites, like Metacritic,IMDB, and Rotten Tomatoes.

# %% [markdown]
# -----
# `all_sites_scores.csv` contains every film that has a Rotten Tomatoes rating, a RT User rating, a Metacritic score, a Metacritic User score, and IMDb score, and at least 30 fan reviews on Fandango.

# %% [markdown]
# Column | Definition
# --- | -----------
# FILM | The film in question
# RottenTomatoes | The Rotten Tomatoes Tomatometer score  for the film
# RottenTomatoes_User | The Rotten Tomatoes user score for the film
# Metacritic | The Metacritic critic score for the film
# Metacritic_User | The Metacritic user score for the film
# IMDB | The IMDb user score for the film
# Metacritic_user_vote_count | The number of user votes the film had on Metacritic
# IMDB_user_vote_count | The number of user votes the film had on IMDb

# %% [markdown]
# ----

# %% [markdown]
# `fandango_scrape.csv` contains every film 538 pulled from Fandango.
#
# Column | Definiton
# --- | ---------
# FILM | The movie
# STARS | Number of stars presented on Fandango.com
# RATING |  The Fandango ratingValue for the film, as pulled from the HTML of each page. This is the actual average score the movie obtained.
# VOTES | number of people who had reviewed the film at the time we pulled it.

# %% [markdown]
# ----

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
fandango = pd.read_csv("fandango_scrape.csv")

# %%
fandango.head()
# Out:
#                           FILM  STARS  RATING  VOTES
# 0  Fifty Shades of Grey (2015)    4.0     3.9  34846
# 1        Jurassic World (2015)    4.5     4.5  34390
# 2       American Sniper (2015)    5.0     4.8  34085
# 3             Furious 7 (2015)    5.0     4.8  33538
# 4            Inside Out (2015)    4.5     4.5  15749

# %%
fandango.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 504 entries, 0 to 503
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   FILM    504 non-null    object
#  1   STARS   504 non-null    float64
#  2   RATING  504 non-null    float64
#  3   VOTES   504 non-null    int64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 15.9+ KB

# %%
fandango.describe()
# Out:
#             STARS      RATING         VOTES
# count  504.000000  504.000000    504.000000
# mean     3.558532    3.375794   1147.863095
# std      1.563133    1.491223   3830.583136
# min      0.000000    0.000000      0.000000
# 25%      3.500000    3.100000      3.000000
# 50%      4.000000    3.800000     18.500000
# 75%      4.500000    4.300000    189.750000
# max      5.000000    5.000000  34846.000000

# %% [markdown]
# ___

# %% [markdown]
# **TASK: Let's explore the relationship between popularity of a film and its rating. Create a scatterplot showing the relationship between rating and votes.**

# %%
plt.figure(figsize=(10, 4), dpi=120)
sns.scatterplot(x='RATING', y='VOTES', data=fandango)
# Out:
# <AxesSubplot:xlabel='RATING', ylabel='VOTES'>

# %% [markdown]
# ___

# %% [markdown]
# **TASK: Calculate the correlation between the columns:**

# %%
fandango.corr()
# Out:
#            STARS    RATING     VOTES
# STARS   1.000000  0.994696  0.164218
# RATING  0.994696  1.000000  0.163764
# VOTES   0.164218  0.163764  1.000000

# %% [markdown]
# ---

# %% [markdown]
# **TASK: Assuming that every row in the FILM title column has the same format:**
#
#     Film Title Name (Year)
#
# **Create a new column that is able to strip the year from the title strings and set this new column as YEAR**

# %%
# my solution

fandango['YEAR'] = fandango['FILM'].str.split(' ').str[-1].str[1:-1]
fandango['YEAR']
# Out:
# 0      2015
# 1      2015
# 2      2015
# 3      2015
# 4      2015
#        ...
# 499    2015
# 500    2015
# 501    2015
# 502    1964
# 503    2012
# Name: YEAR, Length: 504, dtype: object

# %%
# course solution

title = 'Film Title Name (Year)'

# %%
title.split('(')
# Out:
# ['Film Title Name ', 'Year)']

# %%
title.split('(')[-1]
# Out:
# 'Year)'

# %%
title.split('(')[-1].replace(')', '')
# Out:
# 'Year'

# %%
fandango['YEAR'] = fandango['FILM'].apply(lambda title: title.split('(')[-1].replace(')', ''))

# %%
fandango
# Out:
#                                      FILM  STARS  RATING  VOTES  YEAR
# 0             Fifty Shades of Grey (2015)    4.0     3.9  34846  2015
# 1                   Jurassic World (2015)    4.5     4.5  34390  2015
# 2                  American Sniper (2015)    5.0     4.8  34085  2015
# 3                        Furious 7 (2015)    5.0     4.8  33538  2015
# 4                       Inside Out (2015)    4.5     4.5  15749  2015
# ..                                    ...    ...     ...    ...   ...
# 499                      Valiyavan (2015)    0.0     0.0      0  2015
# 500            WWE SummerSlam 2015 (2015)    0.0     0.0      0  2015
# 501       Yagavarayinum Naa Kaakka (2015)    0.0     0.0      0  2015
# 502  Yesterday, Today and Tomorrow (1964)    0.0     0.0      0  1964
# 503                         Zarafa (2012)    0.0     0.0      0  2012
#
# [504 rows x 5 columns]

# %% [markdown]
# ___

# %% [markdown]
# **TASK: How many movies are in the Fandango DataFrame per year?**

# %%
fandango.groupby('YEAR').count()['FILM']
# Out:
# YEAR
# 1964      1
# 2012      1
# 2014     23
# 2015    478
# 2016      1
# Name: FILM, dtype: int64

# %%
fandango['YEAR'].value_counts()
# Out:
# 2015    478
# 2014     23
# 2016      1
# 1964      1
# 2012      1
# Name: YEAR, dtype: int64

# %% [markdown]
# ___

# %% [markdown]
# **TASK: Visualize the count of movies per year with a plot:**

# %%
sns.countplot(x='YEAR', data=fandango)
# Out:
# <AxesSubplot:xlabel='YEAR', ylabel='count'>

# %% [markdown]
# ___

# %% [markdown]
# **TASK: What are the 10 movies with the highest number of votes?**

# %%
fandango.sort_values('VOTES', ascending=False)[:10]
# Out:
#                                                FILM  STARS  RATING  VOTES  \
# 0                       Fifty Shades of Grey (2015)    4.0     3.9  34846
# 1                             Jurassic World (2015)    4.5     4.5  34390
# 2                            American Sniper (2015)    5.0     4.8  34085
# 3                                  Furious 7 (2015)    5.0     4.8  33538
# 4                                 Inside Out (2015)    4.5     4.5  15749
# 5  The Hobbit: The Battle of the Five Armies (2014)    4.5     4.3  15337
# 6               Kingsman: The Secret Service (2015)    4.5     4.2  15205
# 7                                    Minions (2015)    4.0     4.0  14998
# 8                    Avengers: Age of Ultron (2015)    5.0     4.5  14846
# 9                             Into the Woods (2014)    3.5     3.4  13055
#
#    YEAR
# 0  2015
# 1  2015
# 2  2015
# 3  2015
# 4  2015
# 5  2014
# 6  2015
# 7  2015
# 8  2015
# 9  2014

# %%
fandango.nlargest(10, 'VOTES')
# Out:
#                                                FILM  STARS  RATING  VOTES  \
# 0                       Fifty Shades of Grey (2015)    4.0     3.9  34846
# 1                             Jurassic World (2015)    4.5     4.5  34390
# 2                            American Sniper (2015)    5.0     4.8  34085
# 3                                  Furious 7 (2015)    5.0     4.8  33538
# 4                                 Inside Out (2015)    4.5     4.5  15749
# 5  The Hobbit: The Battle of the Five Armies (2014)    4.5     4.3  15337
# 6               Kingsman: The Secret Service (2015)    4.5     4.2  15205
# 7                                    Minions (2015)    4.0     4.0  14998
# 8                    Avengers: Age of Ultron (2015)    5.0     4.5  14846
# 9                             Into the Woods (2014)    3.5     3.4  13055
#
#    YEAR
# 0  2015
# 1  2015
# 2  2015
# 3  2015
# 4  2015
# 5  2014
# 6  2015
# 7  2015
# 8  2015
# 9  2014

# %% [markdown]
# ___

# %% [markdown]
# **TASK: How many movies have zero votes?**

# %%
# first way

fandango[fandango['VOTES'] == 0].count()['FILM']
# Out:
# 69

# %%
# second way

fandango['VOTES'] == 0
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 499     True
# 500     True
# 501     True
# 502     True
# 503     True
# Name: VOTES, Length: 504, dtype: bool

# %%
sum(fandango['VOTES'] == 0)
# Out:
# 69

# %%
# third way

len(fandango[fandango['VOTES'] == 0])
# Out:
# 69

# %% [markdown]
# ---

# %% [markdown]
# **TASK: Create DataFrame of only reviewed films by removing any films that have zero votes.**

# %%
fan_reviewed = fandango[fandango['VOTES'] > 0]

# %%
len(fan_reviewed)
# Out:
# 435

# %%
len(fan_reviewed) + len(fandango[fandango['VOTES'] == 0]) == len(fandango)
# Out:
# True

# %% [markdown]
# ----
#
# **As noted in the article, due to HTML and star rating displays, the true user rating may be slightly different than the rating shown to a user. Let's visualize this difference in distributions.**
#
# **TASK: Create a KDE plot (or multiple kdeplots) that displays the distribution of ratings that are displayed (STARS) versus what the true rating was from votes (RATING). Clip the KDEs to 0-5.**

# %%
sns.kdeplot(x='RATING', data=fan_reviewed)
# Out:
# <AxesSubplot:xlabel='RATING', ylabel='Density'>

# %%
# to keep the plots shown in the same cell, that way it would stack on top of each other

plt.figure(figsize=(10, 4), dpi=150)

sns.kdeplot(x='RATING', data=fan_reviewed, clip=[0, 5], fill=True, label='True Rating')
sns.kdeplot(x='STARS', data=fan_reviewed, clip=[0, 5], fill=True, label='Stars Displayed')

plt.legend(loc=(1.05, .5))

# %% [markdown]
# ___

# %% [markdown]
# **TASK: Let's now actually quantify this discrepancy (несоответствие). Create a new column of the difference between STARS displayed versus true RATING. Calculate this difference with STARS-RATING and round these differences to the nearest decimal point.**

# %%
# my solution

fan_reviewed['STARS_DIFF'] = np.round(fan_reviewed['STARS'] - fan_reviewed['RATING'], 2)
# Out:
# C:\Users\Dell\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# And you'll notice that you may get an error here, it's not truly an error, it's just a __warning__. And this warning is essentially reminding you that fan_reviewed is technically a copy of a slice from a DataFrame. So what that means is essentially reminding you that fan_reviewed actually comes from this fandango dataframe (fan_reviewed = fandango[fandango['VOTES'] > 0]). So in case you didn't want that, you could have also made a full copy. You can always use the copy method in order to make sure you're creating an entirely new dataframe to work with. Keep in mind, the more copies of a dataframe you create, the more RAM memory you're taking up.

# %%
fan_reviewed
# Out:
#                             FILM  STARS  RATING  VOTES  YEAR  STARS_DIFF
# 0    Fifty Shades of Grey (2015)    4.0     3.9  34846  2015         0.1
# 1          Jurassic World (2015)    4.5     4.5  34390  2015         0.0
# 2         American Sniper (2015)    5.0     4.8  34085  2015         0.2
# 3               Furious 7 (2015)    5.0     4.8  33538  2015         0.2
# 4              Inside Out (2015)    4.5     4.5  15749  2015         0.0
# ..                           ...    ...     ...    ...   ...         ...
# 430       That Sugar Film (2015)    5.0     5.0      1  2015         0.0
# 431            The Intern (2015)    5.0     5.0      1  2015         0.0
# 432        The Park Bench (2015)    5.0     5.0      1  2015         0.0
# 433         The Wanted 18 (2015)    5.0     5.0      1  2015         0.0
# 434       Z For Zachariah (2015)    5.0     5.0      1  2015         0.0
#
# [435 rows x 6 columns]

# %%
# course solution

fan_reviewed['STARS_DIFF'] = fan_reviewed['STARS'] - fan_reviewed['RATING']

fan_reviewed['STARS_DIFF'] = fan_reviewed['STARS_DIFF'].round(2)
# Out:
# C:\Users\Dell\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Dell\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %% [markdown]
# ---

# %% [markdown]
# **TASK: Create a count plot to display the number of times a certain difference occurs:**

# %%
plt.figure(figsize=(10, 4), dpi=85)

sns.countplot(data=fan_reviewed, x='STARS_DIFF', palette='magma')
# Out:
# <AxesSubplot:xlabel='STARS_DIFF', ylabel='count'>

# %% [markdown]
# ---

# %% [markdown]
# **TASK: We can see from the plot that one movie was displaying over a 1 star difference than its true rating! What movie had this close to 1 star differential?**

# %%
fan_reviewed[fan_reviewed['STARS_DIFF'] == 1]
# Out:
#                  FILM  STARS  RATING  VOTES  YEAR  STARS_DIFF
# 381  Turbo Kid (2015)    5.0     4.0      2  2015         1.0

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ### Comparison of Fandango Ratings to Other Sites
#
# Let's now compare the scores from Fandango to other movies sites and see how they compare.

# %%
all_sites = pd.read_csv("all_sites_scores.csv")

# %% [markdown]
# ___

# %% [markdown]
# **TASK: Explore the DataFrame columns, info, description.**

# %%
all_sites.head()
# Out:
#                              FILM  RottenTomatoes  RottenTomatoes_User  \
# 0  Avengers: Age of Ultron (2015)              74                   86
# 1               Cinderella (2015)              85                   80
# 2                  Ant-Man (2015)              80                   90
# 3          Do You Believe? (2015)              18                   84
# 4   Hot Tub Time Machine 2 (2015)              14                   28
#
#    Metacritic  Metacritic_User  IMDB  Metacritic_user_vote_count  \
# 0          66              7.1   7.8                        1330
# 1          67              7.5   7.1                         249
# 2          64              8.1   7.8                         627
# 3          22              4.7   5.4                          31
# 4          29              3.4   5.1                          88
#
#    IMDB_user_vote_count
# 0                271107
# 1                 65709
# 2                103660
# 3                  3136
# ...

# %%
all_sites.columns
# Out:
# Index(['FILM', 'RottenTomatoes', 'RottenTomatoes_User', 'Metacritic',
#        'Metacritic_User', 'IMDB', 'Metacritic_user_vote_count',
#        'IMDB_user_vote_count'],
#       dtype='object')

# %%
all_sites.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146 entries, 0 to 145
# Data columns (total 8 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   FILM                        146 non-null    object
#  1   RottenTomatoes              146 non-null    int64
#  2   RottenTomatoes_User         146 non-null    int64
#  3   Metacritic                  146 non-null    int64
#  4   Metacritic_User             146 non-null    float64
#  5   IMDB                        146 non-null    float64
#  6   Metacritic_user_vote_count  146 non-null    int64
#  7   IMDB_user_vote_count        146 non-null    int64
# dtypes: float64(2), int64(5), object(1)
# memory usage: 9.2+ KB

# %%
all_sites.describe()
# Out:
#        RottenTomatoes  RottenTomatoes_User  Metacritic  Metacritic_User  \
# count      146.000000           146.000000  146.000000       146.000000
# mean        60.849315            63.876712   58.808219         6.519178
# std         30.168799            20.024430   19.517389         1.510712
# min          5.000000            20.000000   13.000000         2.400000
# 25%         31.250000            50.000000   43.500000         5.700000
# 50%         63.500000            66.500000   59.000000         6.850000
# 75%         89.000000            81.000000   75.000000         7.500000
# max        100.000000            94.000000   94.000000         9.600000
#
#              IMDB  Metacritic_user_vote_count  IMDB_user_vote_count
# count  146.000000                  146.000000            146.000000
# mean     6.736986                  185.705479          42846.205479
# std      0.958736                  316.606515          67406.509171
# ...

# %% [markdown]
# ---

# %% [markdown]
# ### Rotten Tomatoes
#
# Let's first take a look at Rotten Tomatoes. RT has two sets of reviews, their critics reviews (ratings published by official critics) and user reviews.
# ___
#
# **TASK: Create a scatterplot exploring the relationship between RT Critic reviews and RT User reviews.**

# %%
plt.figure(dpi=120)

sns.scatterplot(data=all_sites, x='RottenTomatoes', y='RottenTomatoes_User')

plt.xlim(0, 100)
plt.ylim(0, 100)

# we get this sort of linear relationship (of course there are also some outliers)
# Out:
# (0.0, 100.0)

# %% [markdown]
# ---

# %% [markdown]
# Let's quantify this difference by comparing the critics ratings and the RT User ratings. We will calculate this with RottenTomatoes-RottenTomatoes_User. Note: Rotten_Diff here is Critics - User Score. So values closer to 0 means aggrement between Critics and Users. Larger positive values means critics rated much higher than users. Larger negative values means users rated much higher than critics.
#
# **TASK: Create a new column based off the difference between critics ratings and users ratings for Rotten Tomatoes. Calculate this with RottenTomatoes-RottenTomatoes_User**

# %%
all_sites['Rotten_Diff'] = all_sites['RottenTomatoes'] - all_sites['RottenTomatoes_User']

# %% [markdown]
# ---

# %% [markdown]
# Let's now compare the overall mean difference. Since we're dealing with differences that could be negative or positive, first take the absolute value of all the differences, then take the mean. This would report back on average to absolute difference between the critics rating versus the user rating.

# %% [markdown]
# **TASK: Calculate the Mean Absolute Difference between RT scores and RT User scores as described above.**

# %% [markdown]
# And if somebody asks you on average, how far off are user ratings than critic's ratings, you can't really just average out all the numbers. Since some are positive and some are negative. You could start getting closer to zero.

# %%
# my solution

np.abs(all_sites['Rotten_Diff']).mean()
# Out:
# 15.095890410958905

# %%
# course solution

all_sites['Rotten_Diff'].apply(abs).mean()
# Out:
# 15.095890410958905

# %%
abs(-4)
# Out:
# 4

# %% [markdown]
# ---

# %% [markdown]
# **TASK: Plot the distribution of the differences between RT Critics Score and RT User Score. There should be negative values in this distribution plot. Feel free to use KDE or Histograms to display this distribution.**

# %%
plt.figure(figsize=(10, 4), dpi=150)

sns.histplot(data=all_sites, x='Rotten_Diff', kde=True, bins=25)

plt.title('RT Critics Score minus RT User Score')
# Out:
# Text(0.5, 1.0, 'RT Critics Score minus RT User Score')

# %% [markdown]
# ---

# %% [markdown]
# **TASK: Now create a distribution showing the *absolute value* difference between Critics and Users on Rotten Tomatoes.**

# %%
plt.figure(figsize=(10, 4), dpi=110)

sns.histplot(x=all_sites['Rotten_Diff'].apply(abs), kde=True, bins=25)

plt.title('Abs Difference between RT Critics Score and RT User Score')
# Out:
# Text(0.5, 1.0, 'Abs Difference between RT Critics Score and RT User Score')

# %% [markdown]
# ---

# %% [markdown]
# **Let's find out which movies are causing the largest differences. First, show the top 5 movies with the largest *negative* difference between Users and RT critics. Since we calculated the difference as Critics Rating - Users Rating, then large negative values imply the users rated the movie much higher on average than the critics did.**

# %% [markdown]
# **TASK: What are the top 5 movies users rated higher than critics on average:**

# %%
all_sites.nsmallest(5, 'Rotten_Diff')[['FILM', 'Rotten_Diff']]
# Out:
#                           FILM  Rotten_Diff
# 3       Do You Believe? (2015)          -66
# 85           Little Boy (2015)          -61
# 105    Hitman: Agent 47 (2015)          -42
# 134    The Longest Ride (2015)          -42
# 125  The Wedding Ringer (2015)          -39

# %% [markdown]
# **TASK: Now show the top 5 movies critics scores higher than users on average.**

# %%
all_sites.nlargest(5, 'Rotten_Diff')[['FILM', 'Rotten_Diff']]
# Out:
#                                  FILM  Rotten_Diff
# 69                  Mr. Turner (2014)           42
# 112                 It Follows (2015)           31
# 115          While We're Young (2015)           31
# 37               Welcome to Me (2015)           24
# 40   I'll See You In My Dreams (2015)           24

# %% [markdown]
# ---

# %% [markdown]
# ### MetaCritic
#
# Metacritic also shows an average user rating versus their official displayed rating.

# %% [markdown]
# ---
# **TASK: Display a scatterplot of the Metacritic Rating versus the Metacritic User rating.**

# %%
plt.figure(figsize=(9, 4), dpi=100)

sns.scatterplot(data=all_sites, x='Metacritic', y='Metacritic_User')

plt.xlim(0, 100)
plt.ylim(0, 10)
# Out:
# (0.0, 10.0)

# %% [markdown]
# ---

# %% [markdown]
# ### IMDB
#
# Notice that both Metacritic and IMDB report back vote counts. Let's analyze the most popular movies.
#
# ---
# **TASK: Create a scatterplot for the relationship between vote counts on MetaCritic versus vote counts on IMDB.**

# %%
all_sites.head(2)
# Out:
#                              FILM  RottenTomatoes  RottenTomatoes_User  \
# 0  Avengers: Age of Ultron (2015)              74                   86
# 1               Cinderella (2015)              85                   80
#
#    Metacritic  Metacritic_User  IMDB  Metacritic_user_vote_count  \
# 0          66              7.1   7.8                        1330
# 1          67              7.5   7.1                         249
#
#    IMDB_user_vote_count  Rotten_Diff
# 0                271107          -12
# 1                 65709            5

# %%
plt.figure(figsize=(10, 4), dpi=100)

sns.scatterplot(data=all_sites, x='Metacritic_user_vote_count', y='IMDB_user_vote_count')
# Out:
# <AxesSubplot:xlabel='Metacritic_user_vote_count', ylabel='IMDB_user_vote_count'>

# %% [markdown]
# ---

# %% [markdown]
# **Notice there are two outliers here. The movie with the highest vote count on IMDB only has about 500 Metacritic ratings. What is this movie?**
#
# **TASK: What movie has the highest IMDB user vote count?**

# %%
all_sites.nlargest(1, 'IMDB_user_vote_count')
# Out:
#                          FILM  RottenTomatoes  RottenTomatoes_User  \
# 14  The Imitation Game (2014)              90                   92
#
#     Metacritic  Metacritic_User  IMDB  Metacritic_user_vote_count  \
# 14          73              8.2   8.1                         566
#
#     IMDB_user_vote_count  Rotten_Diff
# 14                334164           -2

# %% [markdown]
# **TASK: What movie has the highest Metacritic User Vote count?**

# %%
all_sites.nlargest(1, 'Metacritic_user_vote_count')
# Out:
#                          FILM  RottenTomatoes  RottenTomatoes_User  \
# 88  Mad Max: Fury Road (2015)              97                   88
#
#     Metacritic  Metacritic_User  IMDB  Metacritic_user_vote_count  \
# 88          89              8.7   8.3                        2375
#
#     IMDB_user_vote_count  Rotten_Diff
# 88                292023            9

# %% [markdown]
# ---

# %% [markdown]
# ### Fandago Scores vs. All Sites
#
# Finally let's begin to explore whether or not Fandango artificially displays higher ratings than warranted to boost ticket sales.
#
# ---

# %% [markdown]
# **TASK: Combine the fandango table with the all_sites table. Not every movie in the fandango table is in the all_sites table, since some fandango movies have very little or no reviews. We only want to compare movies that are in both DataFrames, so do an *inner* merge to merge together both DataFrames based on the FILM columns.**

# %%
all_sites.head(1)
# Out:
#                              FILM  RottenTomatoes  RottenTomatoes_User  \
# 0  Avengers: Age of Ultron (2015)              74                   86
#
#    Metacritic  Metacritic_User  IMDB  Metacritic_user_vote_count  \
# 0          66              7.1   7.8                        1330
#
#    IMDB_user_vote_count  Rotten_Diff
# 0                271107          -12

# %%
fandango.head(1)
# Out:
#                           FILM  STARS  RATING  VOTES  YEAR
# 0  Fifty Shades of Grey (2015)    4.0     3.9  34846  2015

# %%
df = pd.merge(fandango, all_sites, on='FILM', how='inner')

# %%
df
# Out:
#                                    FILM  STARS  RATING  VOTES  YEAR  \
# 0           Fifty Shades of Grey (2015)    4.0     3.9  34846  2015
# 1                 Jurassic World (2015)    4.5     4.5  34390  2015
# 2                American Sniper (2015)    5.0     4.8  34085  2015
# 3                      Furious 7 (2015)    5.0     4.8  33538  2015
# 4                     Inside Out (2015)    4.5     4.5  15749  2015
# ..                                  ...    ...     ...    ...   ...
# 140  Kumiko, The Treasure Hunter (2015)    3.5     3.5     41  2015
# 141  The Diary of a Teenage Girl (2015)    4.0     3.6     38  2015
# 142            The Wrecking Crew (2015)    4.5     4.2     38  2015
# 143                    Tangerine (2015)    4.0     3.9     36  2015
# 144            Maps to the Stars (2015)    3.5     3.1     35  2015
#
#      RottenTomatoes  RottenTomatoes_User  Metacritic  Metacritic_User  IMDB  \
# ...

# %% [markdown]
# ---

# %% [markdown]
# ### Normalize columns to Fandango STARS and RATINGS 0-5
#
# Notice that RT, Metacritic and IMDB don't use a score between 0-5 stars like Fandango does. In order to do a fair comparison, we need to *normalize* these values so they all fall between 0-5 stars and the relationship between reviews stays the same.
#
# ---
# **TASK: Create new normalized columns for all ratings so they match up within the 0-5 star range shown on Fandango. There are many ways to do this.**
#
# Hint link: https://stackoverflow.com/questions/26414913/normalize-columns-of-pandas-data-frame
#
#
# Easier Hint:
#
# Keep in mind, a simple way to convert ratings:
# * 100/20 = 5
# * 10/2 = 5

# %%
df.describe().loc['max']
# Out:
# STARS                              5.0
# RATING                             4.8
# VOTES                          34846.0
# RottenTomatoes                   100.0
# RottenTomatoes_User               94.0
# Metacritic                        94.0
# Metacritic_User                    9.6
# IMDB                               8.6
# Metacritic_user_vote_count      2375.0
# IMDB_user_vote_count          334164.0
# Rotten_Diff                       42.0
# Name: max, dtype: float64

# %%
df['RT_Norm'] = np.round(df['RottenTomatoes'] / 20, 1) # max value of this field is 100
df['RTU_Norm'] = np.round(df['RottenTomatoes_User'] / 20, 1)

# %%
df['Meta_Norm'] = np.round(df['Metacritic'] / 20, 1)
df['Meta_U_Norm'] = np.round(df['Metacritic_User'] / 2, 1)

# %%
df['IMDB_Norm'] = np.round(df['IMDB'] / 2, 1)

# %%
df.head()
# Out:
#                           FILM  STARS  RATING  VOTES  YEAR  RottenTomatoes  \
# 0  Fifty Shades of Grey (2015)    4.0     3.9  34846  2015              25
# 1        Jurassic World (2015)    4.5     4.5  34390  2015              71
# 2       American Sniper (2015)    5.0     4.8  34085  2015              72
# 3             Furious 7 (2015)    5.0     4.8  33538  2015              81
# 4            Inside Out (2015)    4.5     4.5  15749  2015              98
#
#    RottenTomatoes_User  Metacritic  Metacritic_User  IMDB  \
# 0                   42          46              3.2   4.2
# 1                   81          59              7.0   7.3
# 2                   85          72              6.6   7.4
# 3                   84          67              6.8   7.4
# 4                   90          94              8.9   8.6
#
#    Metacritic_user_vote_count  IMDB_user_vote_count  Rotten_Diff  RT_Norm  \
# 0                         778                179506          -17      1.2
# ...

# %% [markdown]
# ---

# %% [markdown]
# **TASK: Now create a norm_scores DataFrame that only contains the normalized ratings. Include both STARS and RATING from the original Fandango table.**

# %%
df.columns
# Out:
# Index(['FILM', 'STARS', 'RATING', 'VOTES', 'YEAR', 'RottenTomatoes',
#        'RottenTomatoes_User', 'Metacritic', 'Metacritic_User', 'IMDB',
#        'Metacritic_user_vote_count', 'IMDB_user_vote_count', 'Rotten_Diff',
#        'RT_Norm', 'RTU_Norm', 'Meta_Norm', 'Meta_U_Norm', 'IMDB_Norm'],
#       dtype='object')

# %%
norm_scores = df[['STARS', 'RATING', 'RT_Norm', 'RTU_Norm', 'Meta_Norm', 'Meta_U_Norm', 'IMDB_Norm']]

# %%
norm_scores.head()
# Out:
#    STARS  RATING  RT_Norm  RTU_Norm  Meta_Norm  Meta_U_Norm  IMDB_Norm
# 0    4.0     3.9      1.2       2.1        2.3          1.6        2.1
# 1    4.5     4.5      3.6       4.0        3.0          3.5        3.6
# 2    5.0     4.8      3.6       4.2        3.6          3.3        3.7
# 3    5.0     4.8      4.0       4.2        3.4          3.4        3.7
# 4    4.5     4.5      4.9       4.5        4.7          4.4        4.3

# %% [markdown]
# ---
# ---
# ---
#
# ### Comparing Distribution of Scores Across Sites
#
#
# Now the moment of truth! Does Fandango display abnormally high ratings? We already know it pushes displayed RATING higher than STARS, but are the ratings themselves higher than average?
#
# ---
#
# **TASK: Create a plot comparing the distributions of normalized ratings across all sites. There are many ways to do this, but explore the Seaborn KDEplot docs for some simple ways to quickly show this.**
#
# Quick Note if you have issues moving the legend for a seaborn kdeplot: https://github.com/mwaskom/seaborn/issues/2280

# %%
sns.kdeplot(data=norm_scores)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
sns.kdeplot(data=norm_scores, fill=True)
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# But the range is kind of incorrect. I should clip this to zero to five because I know those are the only possible scores.

# %%
plt.figure(figsize=(15, 6), dpi=200)
sns.kdeplot(data=norm_scores, fill=True, clip=[0, 5], palette='Set1')
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# Legends do work a little bit differently in the distribution plots, and they're also still a little rough around the edges.

# %%
# because we're passing in the entire data, we can't actually automatically label all that

sns.kdeplot(data=norm_scores, fill=True, clip=[0, 5], palette='Set1')

plt.legend(loc=(1.05, 0.5))
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# to fix this, look here - https://github.com/mwaskom/seaborn/issues/2280

# %%
def move_legend(ax, new_loc, **kws):
    old_legend = ax.legend_
    handles = old_legend.legendHandles
    labels = [t.get_text() for t in old_legend.get_texts()]
    title = old_legend.get_title().get_text()
    ax.legend(handles, labels, loc=new_loc, title=title, **kws)
    
# move_legend(ax, "upper left")

# %%
fig, ax = plt.subplots(figsize=(15, 6), dpi=200)

sns.kdeplot(data=norm_scores, fill=True, clip=[0, 5], palette='Set1')

move_legend(ax, "upper left")

# %% [markdown]
# __!!! The newest release of Seaborn 0.11.2 has an easier way to move a legend around.__
#
# https://seaborn.pydata.org/generated/seaborn.move_legend.html

# %% [markdown]
# ---

# %% [markdown]
# **Clearly Fandango has an uneven distribution. We can also see that RT critics have the most uniform distribution. Let's directly compare these two.**
#
# **TASK: Create a KDE plot that compare the distribution of RT critic ratings against the STARS displayed by Fandango.**

# %%
fig, ax = plt.subplots(figsize=(15, 6), dpi=100)

sns.kdeplot(data=norm_scores[['RT_Norm', 'STARS']], fill=True, clip=[0, 5], palette='Set1')

move_legend(ax, 'upper left')

# %% [markdown]
# ---

# %% [markdown]
# **OPTIONAL TASK: Create a histplot comparing all normalized scores.**

# %%
plt.figure(figsize=(10, 5))
sns.histplot(data=norm_scores, bins=50)
# Out:
# <AxesSubplot:ylabel='Count'>

# %% [markdown]
# ---

# %% [markdown]
# **TASK: Create a clustermap visualization of all normalized scores. Note the differences in ratings, highly rated movies should be clustered together versus poorly rated movies. Note: This clustermap does not need to have the FILM titles as the index, feel free to drop it for the clustermap.**

# %%
sns.clustermap(norm_scores, cmap='magma', col_cluster=False)

# %% [markdown]
# ---

# %% [markdown]
# **TASK: Based off the Rotten Tomatoes Critic Ratings, what are the top 10 lowest rated movies? What are the normalized scores across all platforms for these movies?**

# %%
norm_scores.head(1)
# Out:
#    STARS  RATING  RT_Norm  RTU_Norm  Meta_Norm  Meta_U_Norm  IMDB_Norm
# 0    4.0     3.9      1.2       2.1        2.3          1.6        2.1

# %%
norm_scores.columns
# Out:
# Index(['STARS', 'RATING', 'RT_Norm', 'RTU_Norm', 'Meta_Norm', 'Meta_U_Norm',
#        'IMDB_Norm'],
#       dtype='object')

# %%
norm_films = df[['FILM', 'STARS', 'RATING', 'RT_Norm', 'RTU_Norm', 'Meta_Norm', 'Meta_U_Norm', 'IMDB_Norm']]

# %%
worst_films = norm_films.nsmallest(10, 'RT_Norm')
worst_films
# Out:
#                              FILM  STARS  RATING  RT_Norm  RTU_Norm  \
# 49  Paul Blart: Mall Cop 2 (2015)    3.5     3.5      0.2       1.8
# 25                 Taken 3 (2015)    4.5     4.1      0.4       2.3
# 28          Fantastic Four (2015)    3.0     2.7      0.4       1.0
# 54             Hot Pursuit (2015)    4.0     3.7      0.4       1.8
# 84        Hitman: Agent 47 (2015)    4.0     3.9      0.4       2.4
# 50       The Boy Next Door (2015)    4.0     3.6      0.5       1.8
# 77             Seventh Son (2015)    3.5     3.2      0.6       1.8
# 78               Mortdecai (2015)    3.5     3.2      0.6       1.5
# 83              Sinister 2 (2015)    3.5     3.3      0.6       1.7
# 87     Unfinished Business (2015)    3.5     3.2      0.6       1.4
#
#     Meta_Norm  Meta_U_Norm  IMDB_Norm
# 49        0.6          1.2        2.2
# 25        1.3          2.3        3.0
# 28        1.4          1.2        2.0
# 54        1.6          1.8        2.4
# ...

# %% [markdown]
# ---

# %% [markdown]
# **FINAL TASK: Visualize the distribution of ratings across all sites for the top 10 worst movies.**

# %%
plt.figure(figsize=(15, 6), dpi=200)

sns.kdeplot(data=worst_films, fill=True, clip=[0, 5], palette='Set1')

plt.title('Ratings for RT Critic\'s 10 Worst Reviewed Films')
# Out:
# Text(0.5, 1.0, "Ratings for RT Critic's 10 Worst Reviewed Films")

# %% [markdown]
# ----
